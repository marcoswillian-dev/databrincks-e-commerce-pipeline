# %%
# %sql
--Ver o estado atual da tabela (antes de otimizar)
DESCRIBE DETAIL e_commerce_2026.silver.pedidos_silver;

# %%
# %sql
OPTIMIZE e_commerce_2026.silver.pedidos_silver
ZORDER BY (order_id);

# %%
# %sql
EXPLAIN SELECT * FROM e_commerce_2026.silver.pedidos_silver WHERE order_id = 'ORD00300';

# %%
# %sql
DESCRIBE DETAIL e_commerce_2026.silver.pedidos_silver;
